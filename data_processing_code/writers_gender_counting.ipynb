# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option("display.max_rows", 20, "display.max_columns", None)

# %%
genderpath = Path('./dialogue_writers_with_gender.csv')
genderdf = pd.read_csv(genderpath, encoding = 'utf-8')

# %%
genderdf.head(10)
# Out:
#    Unnamed: 0 mid    imdb_id  \
# 0          44  m0  tt0147800
# 1         464  m1  tt0103594
# 2         344  m2  tt0179626
# 3         446  m3  tt0062622
# 4         384  m4  tt0083511
# 5         396  m5  tt0119116
# 6         135  m6  tt0134273
# 7         501  m7  tt0095742
# 8         549  m8  tt0097981
# 9          16  m9  tt0052587
#
#                                           writer_ids  \
# 0            ['nm0527581', 'nm0809006', 'nm0000636']
# 1                                      ['nm0097785']
# 2                                      ['nm0381273']
# 3                         ['nm0000040', 'nm0002009']
# 4  ['nm0006854', 'nm0001353', 'nm0343419', 'nm021...
# 5                         ['nm0000108', 'nm0436543']
# 6                                      ['nm0001825']
# 7  ['nm0000127', 'nm0467889', 'nm0001338', 'nm092...
# 8  ['nm0000127', 'nm0804345', 'nm0817468', 'nm009...
# 9            ['nm0359034', 'nm0088726', 'nm0704896']
#
#                                         writer_names writer_gender
# 0  ['Karen McCullah', 'Kirsten Smith', 'William S...         F,F,M
# 1                                     ['Rose Bosch']             F
# 2                                  ['John Herzfeld']             M
# 3            ['Stanley Kubrick', 'Arthur C. Clarke']           M,M
# 4  ['Roger Spottiswoode', 'Walter Hill', 'Larry G...       M,M,M,M
# 5                ['Luc Besson', 'Robert Mark Kamen']           M,M
# 6                            ['Andrew Kevin Walker']             M
# 7  ['Wes Craven', 'William Kotzwinkle', 'Brian He...     M,M,M,M,M
# 8  ['Wes Craven', 'John Skipp', 'Craig Spector', ...       M,M,M,M
# 9  ['Orville H. Hampton', 'Irving Block', 'Jack R...         M,M,M

# %%
# drop extra col indices col
genderdf.drop(genderdf.columns[0],axis=1,inplace=True)

# %%
genderdf # 594 rows
# Out:
#       mid    imdb_id                                         writer_ids  \
# 0      m0  tt0147800            ['nm0527581', 'nm0809006', 'nm0000636']
# 1      m1  tt0103594                                      ['nm0097785']
# 2      m2  tt0179626                                      ['nm0381273']
# 3      m3  tt0062622                         ['nm0000040', 'nm0002009']
# 4      m4  tt0083511  ['nm0006854', 'nm0001353', 'nm0343419', 'nm021...
# ..    ...        ...                                                ...
# 589  m610  tt0032138  ['nm0486538', 'nm0753249', 'nm0941138', 'nm000...
# 590  m611  tt0143145  ['nm0701031', 'nm0905498', 'nm0270761', 'nm000...
# 591  m612  tt0409459            ['nm1733301', 'nm0371684', 'nm0874844']
# 592  m613  tt0295701                                      ['nm0929186']
# 593  m615  tt0072431            ['nm0000698', 'nm0000316', 'nm0791217']
#
#                                           writer_names  \
# 0    ['Karen McCullah', 'Kirsten Smith', 'William S...
# 1                                       ['Rose Bosch']
# 2                                    ['John Herzfeld']
# 3              ['Stanley Kubrick', 'Arthur C. Clarke']
# 4    ['Roger Spottiswoode', 'Walter Hill', 'Larry G...
# ..                                                 ...
# 589  ['Noel Langley', 'Florence Ryerson', 'Edgar Al...
# 590  ['Neal Purvis', 'Robert Wade', 'Bruce Feirstei...
# 591       ['Dave Gibbons', 'David Hayter', 'Alex Tse']
# 592                                    ['Rich Wilkes']
# 593      ['Gene Wilder', 'Mel Brooks', 'Mary Shelley']
#
#                              writer_gender
# 0                                    F,F,M
# 1                                        F
# 2                                        M
# 3                                      M,M
# 4                                  M,M,M,M
# ..                                     ...
# 589  M,F,M,M,M,M,M,M,M,M,M,M,M,M,M,M,M,M,M
# 590                                M,M,M,M
# 591                                  M,M,M
# 592                                      M
# 593                                  M,M,F
#
# [594 rows x 5 columns]

# %%
# convert gender col from string to list of strings
for i, row in genderdf.iterrows():
    gender_str = genderdf.at[i, 'writer_gender']
    gender_list = gender_str.split(',')
    genderdf.at[i, 'writer_gender'] = gender_list

# %%
genderdf
# Out:
#       mid    imdb_id                                         writer_ids  \
# 0      m0  tt0147800            ['nm0527581', 'nm0809006', 'nm0000636']
# 1      m1  tt0103594                                      ['nm0097785']
# 2      m2  tt0179626                                      ['nm0381273']
# 3      m3  tt0062622                         ['nm0000040', 'nm0002009']
# 4      m4  tt0083511  ['nm0006854', 'nm0001353', 'nm0343419', 'nm021...
# ..    ...        ...                                                ...
# 589  m610  tt0032138  ['nm0486538', 'nm0753249', 'nm0941138', 'nm000...
# 590  m611  tt0143145  ['nm0701031', 'nm0905498', 'nm0270761', 'nm000...
# 591  m612  tt0409459            ['nm1733301', 'nm0371684', 'nm0874844']
# 592  m613  tt0295701                                      ['nm0929186']
# 593  m615  tt0072431            ['nm0000698', 'nm0000316', 'nm0791217']
#
#                                           writer_names  \
# 0    ['Karen McCullah', 'Kirsten Smith', 'William S...
# 1                                       ['Rose Bosch']
# 2                                    ['John Herzfeld']
# 3              ['Stanley Kubrick', 'Arthur C. Clarke']
# 4    ['Roger Spottiswoode', 'Walter Hill', 'Larry G...
# ..                                                 ...
# 589  ['Noel Langley', 'Florence Ryerson', 'Edgar Al...
# 590  ['Neal Purvis', 'Robert Wade', 'Bruce Feirstei...
# 591       ['Dave Gibbons', 'David Hayter', 'Alex Tse']
# 592                                    ['Rich Wilkes']
# 593      ['Gene Wilder', 'Mel Brooks', 'Mary Shelley']
#
#                                          writer_gender
# 0                                            [F, F, M]
# 1                                                  [F]
# 2                                                  [M]
# 3                                               [M, M]
# 4                                         [M, M, M, M]
# ..                                                 ...
# 589  [M, F, M, M, M, M, M, M, M, M, M, M, M, M, M, ...
# 590                                       [M, M, M, M]
# 591                                          [M, M, M]
# 592                                                [M]
# 593                                          [M, M, F]
#
# [594 rows x 5 columns]

# %%
# count num of female writers in each movie
genderdf['num_of_female_writers'] = ''

# %%
# see how many F writers each movie has
for i, row in genderdf.iterrows():
    gender_list = genderdf.at[i, 'writer_gender']
    f_count = gender_list.count('F')
    genderdf.at[i,'num_of_female_writers'] = f_count

# %%
genderdf
# Out:
#       mid    imdb_id                                         writer_ids  \
# 0      m0  tt0147800            ['nm0527581', 'nm0809006', 'nm0000636']
# 1      m1  tt0103594                                      ['nm0097785']
# 2      m2  tt0179626                                      ['nm0381273']
# 3      m3  tt0062622                         ['nm0000040', 'nm0002009']
# 4      m4  tt0083511  ['nm0006854', 'nm0001353', 'nm0343419', 'nm021...
# ..    ...        ...                                                ...
# 589  m610  tt0032138  ['nm0486538', 'nm0753249', 'nm0941138', 'nm000...
# 590  m611  tt0143145  ['nm0701031', 'nm0905498', 'nm0270761', 'nm000...
# 591  m612  tt0409459            ['nm1733301', 'nm0371684', 'nm0874844']
# 592  m613  tt0295701                                      ['nm0929186']
# 593  m615  tt0072431            ['nm0000698', 'nm0000316', 'nm0791217']
#
#                                           writer_names  \
# 0    ['Karen McCullah', 'Kirsten Smith', 'William S...
# 1                                       ['Rose Bosch']
# 2                                    ['John Herzfeld']
# 3              ['Stanley Kubrick', 'Arthur C. Clarke']
# 4    ['Roger Spottiswoode', 'Walter Hill', 'Larry G...
# ..                                                 ...
# 589  ['Noel Langley', 'Florence Ryerson', 'Edgar Al...
# 590  ['Neal Purvis', 'Robert Wade', 'Bruce Feirstei...
# 591       ['Dave Gibbons', 'David Hayter', 'Alex Tse']
# 592                                    ['Rich Wilkes']
# 593      ['Gene Wilder', 'Mel Brooks', 'Mary Shelley']
#
#                                          writer_gender num_of_female_writers
# 0                                            [F, F, M]                     2
# 1                                                  [F]                     1
# 2                                                  [M]                     0
# 3                                               [M, M]                     0
# 4                                         [M, M, M, M]                     0
# ..                                                 ...                   ...
# 589  [M, F, M, M, M, M, M, M, M, M, M, M, M, M, M, ...                     1
# 590                                       [M, M, M, M]                     0
# 591                                          [M, M, M]                     0
# 592                                                [M]                     0
# 593                                          [M, M, F]                     1
#
# [594 rows x 6 columns]

# %%
# add col for total num of writers
genderdf['total_num_of_writers'] = ''
for i, row in genderdf.iterrows():
    gender_list = genderdf.at[i, 'writer_gender']
    genderdf.at[i,'total_num_of_writers'] = len(gender_list)

# %%
genderdf
# Out:
#       mid    imdb_id                                         writer_ids  \
# 0      m0  tt0147800            ['nm0527581', 'nm0809006', 'nm0000636']
# 1      m1  tt0103594                                      ['nm0097785']
# 2      m2  tt0179626                                      ['nm0381273']
# 3      m3  tt0062622                         ['nm0000040', 'nm0002009']
# 4      m4  tt0083511  ['nm0006854', 'nm0001353', 'nm0343419', 'nm021...
# ..    ...        ...                                                ...
# 589  m610  tt0032138  ['nm0486538', 'nm0753249', 'nm0941138', 'nm000...
# 590  m611  tt0143145  ['nm0701031', 'nm0905498', 'nm0270761', 'nm000...
# 591  m612  tt0409459            ['nm1733301', 'nm0371684', 'nm0874844']
# 592  m613  tt0295701                                      ['nm0929186']
# 593  m615  tt0072431            ['nm0000698', 'nm0000316', 'nm0791217']
#
#                                           writer_names  \
# 0    ['Karen McCullah', 'Kirsten Smith', 'William S...
# 1                                       ['Rose Bosch']
# 2                                    ['John Herzfeld']
# 3              ['Stanley Kubrick', 'Arthur C. Clarke']
# 4    ['Roger Spottiswoode', 'Walter Hill', 'Larry G...
# ..                                                 ...
# 589  ['Noel Langley', 'Florence Ryerson', 'Edgar Al...
# 590  ['Neal Purvis', 'Robert Wade', 'Bruce Feirstei...
# 591       ['Dave Gibbons', 'David Hayter', 'Alex Tse']
# 592                                    ['Rich Wilkes']
# 593      ['Gene Wilder', 'Mel Brooks', 'Mary Shelley']
#
#                                          writer_gender num_of_female_writers  \
# 0                                            [F, F, M]                     2
# 1                                                  [F]                     1
# 2                                                  [M]                     0
# 3                                               [M, M]                     0
# 4                                         [M, M, M, M]                     0
# ..                                                 ...                   ...
# 589  [M, F, M, M, M, M, M, M, M, M, M, M, M, M, M, ...                     1
# 590                                       [M, M, M, M]                     0
# 591                                          [M, M, M]                     0
# 592                                                [M]                     0
# 593                                          [M, M, F]                     1
#
#     total_num_of_writers
# 0                      3
# 1                      1
# 2                      1
# 3                      2
# 4                      4
# ..                   ...
# 589                   19
# 590                    4
# 591                    3
# 592                    1
# 593                    3
#
# [594 rows x 7 columns]

# %%
# calculate how many movies have atleast 1 female writer
atleast_one_f_writer = genderdf[genderdf['num_of_female_writers'] > 0]
atleast_one_f_writer
len(atleast_one_f_writer) # 99 out of 595
# Out:
# 99

# %%
# add col to genderdf to check if all writers for each movie are female
genderdf['all_female_writers'] = ''

# %%
for i, row in genderdf.iterrows():
    gender_list = genderdf.at[i, 'writer_gender']
    if gender_list.count('M') == 0:
        genderdf.at[i, 'all_female_writers'] = True
    else:
        genderdf.at[i, 'all_female_writers'] = False

# %%
# calculate how many movies have all female writers
all_female = genderdf[genderdf['all_female_writers']  == True]
all_female
len(all_female) # 22
# Out:
# 22

# %%
# value counts for num_of_female_writers
genderdf.num_of_female_writers.value_counts()
# none = .83, 1 = .14, 2 = 0.02, 3 = .005
# Out:
# 0    495
# 1     83
# 2     13
# 3      3
# Name: num_of_female_writers, dtype: int64

# %%
# export complete writer gender data to csv
genderdf.to_csv("dialogue_writers_gender_with_counts.csv", encoding='utf-8')
